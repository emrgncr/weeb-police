# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/controlled_traindata.rar controlled_traindata.rar

# %%
# !rm -rf .ipynb_checkpoints

# %%
os.listdir()
# Out:
# ['.config',
#  'controlled_traindata.rar',
#  'drive',
#  'controlled_traindata',
#  'sample_data']

# %%
# %cd ..
# Out:
# /content

# %%
# %mkdir out

# %%
# %mkdir ml
# !unzip "up10000.zip" -d "ml/" 
# %cd ml
# %cd ..
# !ls

# %%
# !ls

# %%
# !unzip "up10000.zip"

# %%
# !unrar x "controlled_traindata.rar"

# %%
# !tar -xvf "ml3.tar"

# %%
# !ls
# Out:
# drive  ml  out	sample_data

# %%
from PIL import Image
from PIL import ImageChops
import os.path
import shutil
from os import path
import numpy as np
from matplotlib.image import imread

# %%
path1 = "ml/anime/img_"
path2 = "ml/avatars/imga_"
outh = "out/"
for a in range(20000):
  fn = path1 + str(a) + ".jpg"
  if os.path.isfile(fn):
    im = Image.open(fn).convert('L')
    rim = im.resize((12,12))
    rim.save(outh + "img_" + str(a) + ".jpg",optimize = True,quality = 100)
  fn = path2 + str(a) + ".jpg"
  if os.path.isfile(fn):
    im = Image.open(fn).convert('L')
    rim = im.resize((12,12))
    rim.save(outh + "imga_" + str(a) + ".jpg",optimize = True,quality = 100)

# %%
print(ima.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-364b952413c5> in <module>()
# ----> 1 print(ima.shape)
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'

# %%
# %ls
# Out:
# controlled_traindata/  controlled_traindata.rar  drive/  sample_data/

# %%
#check time
import time
#imread
start = time.time()
read1 = imread("out/img_0.jpg")
read2 = imread("out/img_1.jpg")
print("2x imread took " + str(time.time()-start))
start2 = time.time()
ts = np.array_equal(read1,read2)
print("imcompare took " + str(time.time()-start2))
print("np took total of" + str(time.time()-start))
start = time.time()
reo1 = Image.open("out/img_0.jpg")
reo2 = Image.open("out/img_1.jpg")
print("2x image.open took " + str(time.time()-start))
start2 = time.time()
ts = list(reo1.getdata()) == list(reo2.getdata())
print("getdata took " + str(time.time()-start2))
print("pil took total of" + str(time.time()-start))
# Out:
# 2x imread took 0.001956939697265625
# imcompare took 0.0005276203155517578
# np took total of0.003830432891845703
# 2x image.open took 0.0005090236663818359
# getdata took 0.0003495216369628906
# pil took total of0.0024254322052001953

# %%
#@title detect same images w this. if sad_des = True, delete same images { display-mode: "form" }
sad_des = True #@param {type:"boolean"}
#detect same images w this
#sad_des = True #if true deletes duplicates
count = 0
filepath = "controlled_traindata/"
avt = "avatars/"
anm = "controlled_traindata/anime/"
#anm = "anime/"
#anm = "avatars_rescaled3/"
a = 0 # last 2904
b = 1
max = 3150
min = 0
#avatar_
#avatar_xd
#avatarxda_
fpath1 = "img_" #@param {type:"string"}
fpath2 = "img_"
fpath3 = "avatarxda_"
path1 =""
path2 =""
for a in range(min,(max) + 1):
  path1 = anm
  if a % 20 == 0:
    print("at " + str(a))
  if a > max:
    if a > 2*max:
      path1 += fpath3
    else:
      path1 += fpath2
  else:
    path1 += fpath1
  path1 += str(a)
  path1 += ".jpg"
  if not path.exists(path1):
    continue
  ima = imread(path1)
  for b in range(a+1,(max) + 1):
    path2 = anm
    path3 = filepath + avt
    if b > max:
      if b > 2*max:
        path2 += fpath3
      else:
        path2 += fpath2
    else:
      path2 += fpath1
      path3 += fpath1
    path2 += str(b)
    path3 += str(b)
    path2 += ".jpg"
    path3 += ".jpg"
    if not path.exists(path2):
      continue
    imb = imread(path2)
    #print(ima.shape)
    #print(imb.shape)
    #image_one = Image.open(path1).convert('RGB')
    #image_two = Image.open(path2).convert('RGB')
    #diff_err = mse(ima,imb)
    #print("for " + path1 + " and "+path2+" MSE = " + str(diff_err))
    if np.array_equal(ima,imb):
      print(f"images are similar: "+"\n"+path1  +"   " + path2+"\n total deleted = "+ str(count))
      count += 1
      if sad_des == True:
        os.remove(path2)
        os.remove(path3)
# Out:
# at 0
# at 20
# at 40
# at 60
# at 80
# at 100
# at 120
# at 140
# at 160
# at 180
# at 200
# at 220
# at 240
# at 260
# at 280
# at 300
# at 320
# at 340
# at 360
# at 380
# at 400
# at 420
# at 440
# at 460
# at 480
# at 500
# at 520
# at 540
# at 560
# at 580
# at 600
# at 620
# at 640
# at 660
# at 680
# at 700
# at 720
# at 740
# at 760
# at 780
# at 800
# at 820
# at 840
# at 860
# at 880
# at 900
# at 920
# at 940
# at 960
# at 980
# at 1000
# at 1020
# at 1040
# at 1060
# at 1080
# at 1100
# at 1120
# at 1140
# at 1160
# at 1180
# at 1200
# at 1220
# at 1240
# at 1260
# at 1280
# at 1300
# at 1320
# at 1340
# at 1360
# at 1380
# at 1400
# at 1420
# at 1440
# at 1460
# at 1480
# at 1500
# at 1520
# at 1540
# at 1560
# at 1580
# at 1600
# at 1620
# at 1640
# at 1660
# at 1680
# at 1700
# at 1720
# at 1740
# at 1760
# at 1780
# at 1800
# at 1820
# at 1840
# at 1860
# at 1880
# at 1900
# at 1920
# at 1940
# at 1960
# at 1980
# at 2000
# at 2020
# at 2040
# at 2060
# at 2080
# ...

# %%
#@title detect same images w this. if sad_des = True, delete same images { display-mode: "form" }
sad_des = True #@param {type:"boolean"}
#detect same images w this
#sad_des = True #if true deletes duplicates
#USES PIL NOT NP
count = 0
filepath = "ml/"
avt = "avatars/"
anm = "out/"
#anm = "anime/"
#anm = "avatars_rescaled3/"
a = 0 # last at 5100
b = 1
max = 20000
min = 10000
#avatar_
#avatar_xd
#avatarxda_
fpath1 = "imga_" #@param {type:"string"}
fpath2 = "imga_"
fpath3 = "avatarxda_"
path1 =""
path2 =""
for a in range(min,(max) + 1):
  path1 = anm
  if a % 20 == 0:
    print("at " + str(a))
  if a % 2000 == 0:
    backupy(a)
  if a > max:
    if a > 2*max:
      path1 += fpath3
    else:
      path1 += fpath2
  else:
    path1 += fpath1
  path1 += str(a)
  path1 += ".jpg"
  if not path.exists(path1):
    continue
  ima = Image.open(path1)
  for b in range(a+1,(max) + 1):
    path2 = anm
    path3 = filepath + avt
    if b > max:
      if b > 2*max:
        path2 += fpath3
      else:
        path2 += fpath2
    else:
      path2 += fpath1
      path3 += fpath1
    path2 += str(b)
    path3 += str(b)
    path2 += ".jpg"
    path3 += ".jpg"
    if not path.exists(path2):
      continue
    imb = Image.open(path2)
    #print(ima.shape)
    #print(imb.shape)
    #image_one = Image.open(path1).convert('RGB')
    #image_two = Image.open(path2).convert('RGB')
    #diff_err = mse(ima,imb)
    #print("for " + path1 + " and "+path2+" MSE = " + str(diff_err))
    if list(ima.getdata()) == list(imb.getdata()):
      print(f"images are similar: "+"\n"+path1  +"   " + path2+"\n total deleted = "+ str(count))
      count += 1
      if sad_des == True:
        os.remove(path2)
        os.remove(path3)

# %%
#!zip "/content/drive/My Drive/up.zip" "ml/anime/img_0.jpg"
import shutil
def backupy(a):
  shutil.make_archive("/content/drive/My Drive/up"+str(a), 'zip', "ml")

# %%
#get how many files are left
paths = os.listdir("ml/avatars")
print(len(paths))
# Out:
# 19570

# %%
#@title Manually delete images
duplicates = "avatar_10000.jpg avatar_10009.jpg avatar_10090.jpg avatar_3606.jpg avatar_3624.jpg avatar_4566.jpg avatar_4573.jpg" #@param {type:"string"}
filepath = "ml/anime_rescaled/" #@param {type:"string"}

def dupsil(dx,fp):
  if dx == "Seperate with space":
    return
  dxlist = dx.rsplit(" ")
  for index in dxlist:
    path1 = filepath + index
    if not path.exists(path1):
      continue
    os.remove(path1)
    print(path1 + " has been removed")

dupsil(duplicates,filepath)
# Out:
# ml/anime_rescaled/avatar_10000.jpg has been removed
# ml/anime_rescaled/avatar_10009.jpg has been removed
# ml/anime_rescaled/avatar_10090.jpg has been removed
# ml/anime_rescaled/avatar_3606.jpg has been removed
# ml/anime_rescaled/avatar_3624.jpg has been removed
# ml/anime_rescaled/avatar_4566.jpg has been removed
# ml/anime_rescaled/avatar_4573.jpg has been removed

# %%
import pathlib
#!cp '/content/drive/My Drive/ml/'
data_dir = pathlib.Path('/content/drive/My Drive/ml/')
#dont use this

# %%
import pathlib
#dataset_url = "https://drive.google.com/uc?export=download&id=1eRd1LGQfEg6zccGFxowgToDAVznqTiQq"
#data_dir = tf.keras.utils.get_file('ml', origin="ml3.tar", untar=True)
data_dir = pathlib.Path("controlled_traindata")

# %%
# %cd ..
# Out:
# /content

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 21687

# %%
anime = list(data_dir.glob('anime/*'))
PIL.Image.open(str(anime[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=92x92 at 0x7F8AE6989790>

# %%
batch_size = 32
img_height = 92
img_width = 92

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=6931,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 21687 files belonging to 2 classes.
# Using 17350 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=6931,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a1d7e70a411d> in <module>()
#       1 val_ds = tf.keras.preprocessing.image_dataset_from_directory(
# ----> 2   data_dir,
#       3   validation_split=0.2,
#       4   subset="validation",
#       5   seed=6931,
#
# NameError: name 'data_dir' is not defined

# %%
#class_names = train_ds.class_names
class_names = ["anime","avatar"]
print(class_names)
# Out:
# ['anime', 'avatar']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 92, 92, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
num_classes = 2

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# rescaling_1 (Rescaling)      (None, 92, 92, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 92, 92, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 46, 46, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 23, 23, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 64)        0
# ...

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 543/543 [==============================] - 154s 271ms/step - loss: 0.2877 - accuracy: 0.8915 - val_loss: 0.2495 - val_accuracy: 0.9094
# Epoch 2/10
# 543/543 [==============================] - 145s 267ms/step - loss: 0.2289 - accuracy: 0.9122 - val_loss: 0.2156 - val_accuracy: 0.9246
# Epoch 3/10
# 543/543 [==============================] - 144s 266ms/step - loss: 0.1997 - accuracy: 0.9234 - val_loss: 0.1891 - val_accuracy: 0.9334
# Epoch 4/10
# 543/543 [==============================] - 144s 266ms/step - loss: 0.1743 - accuracy: 0.9339 - val_loss: 0.1816 - val_accuracy: 0.9366
# Epoch 5/10
# 543/543 [==============================] - 144s 266ms/step - loss: 0.1523 - accuracy: 0.9406 - val_loss: 0.1772 - val_accuracy: 0.9380
# Epoch 6/10
# 543/543 [==============================] - 144s 266ms/step - loss: 0.1263 - accuracy: 0.9520 - val_loss: 0.1771 - val_accuracy: 0.9366
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# sequential_1 (Sequential)    (None, 92, 92, 3)         0
# _________________________________________________________________
# rescaling_2 (Rescaling)      (None, 92, 92, 3)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 92, 92, 16)        448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 46, 46, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 46, 46, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 23, 23, 64)        18496
# ...

# %%
epochs = 25


history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/25
# 543/543 [==============================] - 174s 321ms/step - loss: 0.0833 - accuracy: 0.9695 - val_loss: 0.1723 - val_accuracy: 0.9479
# Epoch 2/25
# 543/543 [==============================] - 167s 308ms/step - loss: 0.0820 - accuracy: 0.9682 - val_loss: 0.1932 - val_accuracy: 0.9391
# Epoch 3/25
# 543/543 [==============================] - 167s 308ms/step - loss: 0.0792 - accuracy: 0.9698 - val_loss: 0.1574 - val_accuracy: 0.9571
# Epoch 4/25
# 543/543 [==============================] - 167s 308ms/step - loss: 0.0843 - accuracy: 0.9692 - val_loss: 0.1777 - val_accuracy: 0.9520
# Epoch 5/25
# 543/543 [==============================] - 167s 308ms/step - loss: 0.0810 - accuracy: 0.9688 - val_loss: 0.1548 - val_accuracy: 0.9573
# Epoch 6/25
# 543/543 [==============================] - 168s 309ms/step - loss: 0.0737 - accuracy: 0.9722 - val_loss: 0.1824 - val_accuracy: 0.9474
# Epoch 7/25
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
sunflower_url = "https://drive.google.com/uc?export=download&id=1YLqiUZ_jPPdivzGxNqg1Y16q-uL8a4_X"
sunflower_path = tf.keras.utils.get_file('leddit', origin=sunflower_url)

img = keras.preprocessing.image.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
plt.imshow(img)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch


predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to avatar with a 100.00 percent confidence.

# %%
img = imread("gec1.jpg")
plt.imshow(img)
#img_array = keras.preprocessing.image.img_to_array(img)
img_array = img
img_array = tf.expand_dims(img_array, 0) # Create a batch


predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to avatar with a 100.00 percent confidence.

# %%
model.save("/content/drive/My Drive/calisan_/ml9/")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/calisan_/ml9/assets

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpbz92_j2p/assets

# %%
converter = tf.lite.TFLiteConverter.from_saved_model("/content/drive/My Drive/calisan_/ml9/") # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('model2.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
# !ls
# Out:
# drive  ml  ml3.tar  model.tflite  sample_data

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
import shutil
shutil.copy("model.tflite","/content/drive/My Drive/model.tflite")
# !ls
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpfo5z2b0s/assets
# INFO:tensorflow:Assets written to: /tmp/tmpfo5z2b0s/assets
# drive  ml  ml3.tar  model.tflite  sample_data

# %%
model = keras.models.load_model("/content/drive/My Drive/calisan_/ml9/")

# %%
# !ls
# Out:
# drive  ml  ml3.tar  model.tflite  sample_data  test  test.tar

# %%
# !cp /content/drive/MyDrive/test3.rar test3.rar

# %%
# !unrar x "test3.rar"

# %%
i2_path = 'test3/'
i2_name = 'img_'
isay = 5800
import os.path
import shutil
from os import path
while isay<10000:
  i_path = i2_path+i2_name+str(isay)+'.jpg'
  iin = i2_name+str(isay)+'.jpg'
  if isay == 1239:
    isay += 1
    continue
  if not path.exists(i_path):
    isay += 1
    continue
  try:
    img = keras.preprocessing.image.load_img(
        i_path, target_size=(img_height, img_width)
    )
  except:
    print("HATAAA " + str(isay))
    isay += 1
    continue
  #plt.imshow(img)
  img_array = keras.preprocessing.image.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0) # Create a batch
  predictions = model.predict(img_array)
  score = tf.nn.softmax(predictions[0])

  print(
      "This image most likely belongs to {} with a {:.2f} percent confidence."
      .format(class_names[np.argmax(score)], 100 * np.max(score))
  )
  print(isay)
  isay = 20000
  continue
  mscore = 100 * np.max(score)
  if np.argmax(score) == 0:
    if mscore >= 85:
      shutil.copy(i_path,"/content/drive/My Drive/test2/85/"+iin)
    elif mscore >=80:
      shutil.copy(i_path,"/content/drive/My Drive/test2/80/"+iin)
    elif mscore >= 70:
      shutil.copy(i_path,"/content/drive/My Drive/test2/70/"+iin)
    elif mscore >= 60:
      shutil.copy(i_path,"/content/drive/My Drive/test2/60/"+iin)
    else:
      shutil.copy(i_path,"/content/drive/My Drive/test2/50/"+iin)
  else:
    shutil.copy(i_path,"/content/drive/My Drive/test2/avt/"+iin)
  isay += 1
# Out:
# This image most likely belongs to anime with a 87.15 percent confidence.
# 5800

# %%
sunflower_url = "https://drive.google.com/uc?export=download&id=1hB6lgvBrmh0bEBYft7lBWIrdIRii3Y3Y"
sunflower_path = tf.keras.utils.get_file('cinnamon', origin=sunflower_url)
class_names = ["anime","avatar"]
img = keras.preprocessing.image.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
plt.imshow(img)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch


predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print(
      "This image most likely belongs to {} with a {:.2f} percent confidence."
      .format(class_names[np.argmax(score)], 100 * np.max(score))
  )
print(
    predictions
)
print(score)
# Out:
# This image most likely belongs to anime with a 100.00 percent confidence.
# [[ 3.8913548 -6.8196473]]
# tf.Tensor([9.9997771e-01 2.2297754e-05], shape=(2,), dtype=float32)
